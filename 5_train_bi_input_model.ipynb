# %% [markdown]
# # Bi-Input Model Training

# %% [markdown]
# In this notebook the basic model is trained on the normalized dataset.

# %%
from bi_input_model import BiInputModel

# %% [markdown]
# Load dataset

# %%
import torch

dataset_path = "data/main_dataset/base_open_walls/"

# load test input/output data
inputs = torch.load(dataset_path + "inputs.pt")
outputs = torch.load(dataset_path + "outputs.pt")

inputs.shape, outputs.shape
# Out:
# (torch.Size([896, 2, 21, 21]), torch.Size([896, 2, 21, 21]))

# %% [markdown]
# Normalize data

# %%
from data.normalization import normalize_data, denormalize_data

inputs, outputs = normalize_data(inputs, outputs, dataset_path + "min_max.yaml")

# %% [markdown]
# Inspect one input/output sample

# %%
from plotting import plot_data_samples

plot_data_samples(inputs, outputs, title="Input and Output Data")

# %% [markdown]
# Create training, validation and test data splits

# %%
import torch

# random sorting of input-output pairs
perm = torch.randperm(len(inputs)) # generate random permutation indices
inputs = inputs[perm]
outputs = outputs[perm]

# split data points into train, validation and test sets
x_train, y_train = inputs[:int(0.8 * len(inputs))], outputs[:int(0.8 * len(outputs))] # 80% of data
x_val, y_val = inputs[int(0.8 * len(inputs)):int(0.9 * len(inputs))], outputs[int(0.8 * len(outputs)):int(0.9 * len(outputs))] # 10% of data
x_test, y_test = inputs[int(0.9 * len(inputs)):], outputs[int(0.9 * len(outputs)):] # 10% of data

# %% [markdown]
# We take the training and validation data points and create a loader with them to train the model

# %%
import torch

batch_size = 50

# create tensor dataset and dataloader
train_dataset = torch.utils.data.TensorDataset(x_train, y_train)
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size)

val_dataset = torch.utils.data.TensorDataset(x_val, y_val)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size)

# %%
x_train.shape, y_train.shape
# Out:
# (torch.Size([716, 2, 21, 21]), torch.Size([716, 2, 21, 21]))

# %% [markdown]
# Instantiate and train the model with the data

# %%
model = BiInputModel()
model.fit(train_dataloader, val_dataloader, learning_rate=0.0005, epochs=4000)
# Out:
# ----------
# Epoch 0
# Training loss: 0.015827666968107224
# Validation loss: 0.01595192588865757
# ----------
# ----------
# Epoch 50
# Training loss: 0.00014759281475562602
# Validation loss: 0.00016939859051490203
# ----------
# ----------
# Epoch 100
# Training loss: 4.14716632803902e-05
# Validation loss: 4.064552558702417e-05
# ----------
# ----------
# Epoch 150
# Training loss: 2.3278593289433047e-05
# Validation loss: 2.3384194719255902e-05
# ----------
# ----------
# Epoch 200
# Training loss: 2.5993525923695415e-05
# Validation loss: 2.9129999347787816e-05
# ----------
# ----------
# Epoch 250
# Training loss: 2.5504477889626287e-05
# Validation loss: 3.4181068258476444e-05
# ----------
# ----------
# Epoch 300
# Training loss: 8.470397006021813e-06
# Validation loss: 8.341660304722609e-06
# ----------
# ----------
# Epoch 350
# Training loss: 8.230755156546365e-06
# Validation loss: 1.128120175053482e-05
# ----------
# ----------
# Epoch 400
# Training loss: 1.1558027836144902e-05
# Validation loss: 1.1306799024168868e-05
# ----------
# ----------
# Epoch 450
# Training loss: 9.17326360649895e-06
# Validation loss: 1.1109108072560048e-05
# ----------
# ----------
# Epoch 500
# Training loss: 1.1107364116469398e-05
# Validation loss: 9.947807939170161e-06
# ----------
# ----------
# Epoch 550
# Training loss: 7.5949028541799635e-06
# Validation loss: 7.713862487435108e-06
# ----------
# ----------
# Epoch 600
# Training loss: 9.209391464537475e-06
# Validation loss: 1.6712963770260103e-05
# ----------
# ----------
# Epoch 650
# Training loss: 3.102489472439629e-06
# Validation loss: 3.148083578707883e-06
# ----------
# ----------
# Epoch 700
# Training loss: 8.311039891850669e-06
# Validation loss: 1.2429691651050234e-05
# ----------
# ----------
# Epoch 750
# Training loss: 9.406528988620266e-06
# Validation loss: 9.557402336213272e-06
# ----------
# ----------
# Epoch 800
# Training loss: 4.022239863843424e-06
# Validation loss: 7.125292768250802e-06
# ----------
# ----------
# Epoch 850
# Training loss: 1.0243053111480549e-05
# Validation loss: 1.3896173641114729e-05
# ----------
# ----------
# Epoch 900
# Training loss: 2.0148115709162084e-06
# Validation loss: 2.1838720840605674e-06
# ----------
# ----------
# Epoch 950
# Training loss: 4.961495505995117e-06
# Validation loss: 6.516409484902397e-06
# ----------
# ----------
# Epoch 1000
# Training loss: 1.2005725693597924e-06
# Validation loss: 1.3885736507290858e-06
# ----------
# ----------
# Epoch 1050
# Training loss: 8.359628736798186e-06
# Validation loss: 6.653940772594069e-06
# ----------
# ----------
# Epoch 1100
# Training loss: 1.9213437099097064e-06
# Validation loss: 2.1816487105752458e-06
# ----------
# ----------
# Epoch 1150
# Training loss: 6.59683792036958e-07
# Validation loss: 6.398778964467056e-07
# ----------
# ----------
# Epoch 1200
# Training loss: 2.1968739929434378e-06
# Validation loss: 3.0488444053844432e-06
# ----------
# ----------
# Epoch 1250
# Training loss: 1.4022560890225577e-06
# Validation loss: 2.414498680991528e-06
# ----------
# ----------
# Epoch 1300
# Training loss: 2.4817495614115614e-06
# Validation loss: 2.1551611553149996e-06
# ----------
# ----------
# Epoch 1350
# Training loss: 4.4825337681686506e-06
# Validation loss: 4.571359568217304e-06
# ----------
# ----------
# Epoch 1400
# Training loss: 1.2764229495587642e-06
# Validation loss: 1.085742781015142e-06
# ----------
# ----------
# Epoch 1450
# Training loss: 1.601994540578744e-06
# Validation loss: 2.2186601427165442e-06
# ----------
# ----------
# Epoch 1500
# Training loss: 9.324875804850308e-07
# Validation loss: 5.75959063553455e-07
# ----------
# ----------
# Epoch 1550
# Training loss: 3.108491455350304e-06
# Validation loss: 2.418401663817349e-06
# ----------
# ----------
# Epoch 1600
# Training loss: 1.3083232488497742e-06
# Validation loss: 2.066882757389976e-06
# ----------
# ----------
# Epoch 1650
# Training loss: 1.8704507738220855e-06
# Validation loss: 2.5618842300900724e-06
# ----------
# ----------
# Epoch 1700
# Training loss: 3.5347858329259907e-07
# Validation loss: 3.681511770992074e-07
# ----------
# ----------
# Epoch 1750
# Training loss: 2.3317334125749767e-06
# Validation loss: 2.7572881435844465e-06
# ----------
# ----------
# Epoch 1800
# Training loss: 1.9606900423241314e-06
# Validation loss: 2.4265322053906857e-06
# ----------
# ----------
# Epoch 1850
# Training loss: 2.4699211280676536e-06
# Validation loss: 4.370869419290102e-06
# ----------
# ----------
# Epoch 1900
# Training loss: 3.7955292100377847e-06
# Validation loss: 5.902652901568217e-06
# ----------
# ----------
# Epoch 1950
# Training loss: 7.505497592319443e-07
# Validation loss: 8.153701003266178e-07
# ----------
# ----------
# Epoch 2000
# Training loss: 5.39146753908426e-07
# Validation loss: 4.549222154537347e-07
# ----------
# ----------
# Epoch 2050
# Training loss: 3.9607693906873465e-06
# Validation loss: 5.894219839319703e-06
# ----------
# ----------
# Epoch 2100
# Training loss: 1.4181434835336404e-06
# Validation loss: 1.169907818621141e-06
# ----------
# ----------
# Epoch 2150
# Training loss: 3.321184181004355e-07
# Validation loss: 3.006264250871027e-07
# ----------
# ----------
# Epoch 2200
# Training loss: 1.7207794371643104e-06
# Validation loss: 2.179751732001023e-06
# ----------
# ----------
# Epoch 2250
# Training loss: 2.5034418627001287e-07
# Validation loss: 2.831645247169945e-07
# ----------
# ----------
# Epoch 2300
# Training loss: 8.921654739424412e-07
# Validation loss: 9.943401266809815e-07
# ----------
# ----------
# Epoch 2350
# Training loss: 2.2776430341764353e-07
# Validation loss: 1.9896742031733083e-07
# ----------
# ----------
# Epoch 2400
# Training loss: 4.4521641484607244e-07
# Validation loss: 2.812305268662385e-07
# ----------
# ----------
# Epoch 2450
# Training loss: 2.595969874619186e-07
# Validation loss: 3.0438270925969846e-07
# ----------
# ----------
# Epoch 2500
# Training loss: 2.3208535537833086e-07
# Validation loss: 2.768283451359821e-07
# ----------
# ----------
# Epoch 2550
# Training loss: 2.3277577554381423e-07
# Validation loss: 2.3845488783535984e-07
# ----------
# ----------
# Epoch 2600
# Training loss: 1.6124391777339042e-07
# Validation loss: 1.8258018741335036e-07
# ----------
# ----------
# Epoch 2650
# Training loss: 4.7537096747873875e-07
# Validation loss: 4.3184016362829425e-07
# ----------
# ----------
# Epoch 2700
# Training loss: 6.205144700288656e-07
# Validation loss: 4.6908591855299164e-07
# ----------
# ----------
# Epoch 2750
# Training loss: 8.371708304366621e-07
# Validation loss: 1.1186221513526107e-06
# ----------
# ----------
# Epoch 2800
# Training loss: 2.865326109713351e-07
# Validation loss: 2.2824858092462819e-07
# ----------
# ----------
# Epoch 2850
# Training loss: 4.46525262987052e-07
# Validation loss: 2.894421129440161e-07
# ----------
# ----------
# Epoch 2900
# Training loss: 1.4807896775437257e-07
# Validation loss: 1.748165630033327e-07
# ----------
# ----------
# Epoch 2950
# Training loss: 1.459744225940085e-06
# Validation loss: 2.0573535266521503e-06
# ----------
# ----------
# Epoch 3000
# Training loss: 1.2046523352182703e-06
# Validation loss: 1.4251963307287951e-06
# ----------
# ----------
# Epoch 3050
# Training loss: 2.199492286081295e-07
# Validation loss: 2.8436983257051907e-07
# ----------
# ----------
# Epoch 3100
# Training loss: 2.1640931890942738e-07
# Validation loss: 2.0295335900755163e-07
# ----------
# ----------
# Epoch 3150
# Training loss: 1.4954553080315236e-06
# Validation loss: 2.520566454222717e-06
# ----------
# ----------
# Epoch 3200
# Training loss: 4.811889084521681e-06
# Validation loss: 6.1925884438096546e-06
# ----------
# ----------
# Epoch 3250
# Training loss: 8.022316819733533e-07
# Validation loss: 1.3650837900058832e-06
# ----------
# ----------
# Epoch 3300
# Training loss: 5.149707931195735e-07
# Validation loss: 4.039689969204119e-07
# ----------
# ----------
# Epoch 3350
# Training loss: 4.110092675091437e-07
# Validation loss: 4.5353007749326935e-07
# ----------
# ----------
# Epoch 3400
# Training loss: 3.184957222401863e-07
# Validation loss: 4.2040387882025243e-07
# ----------
# ----------
# Epoch 3450
# Training loss: 2.613987817312591e-07
# Validation loss: 3.0787579419211397e-07
# ----------
# ----------
# Epoch 3500
# Training loss: 1.5462322835446685e-06
# Validation loss: 1.8481072743270488e-06
# ----------
# ----------
# Epoch 3550
# Training loss: 2.5564593215676723e-06
# Validation loss: 2.7576912771110074e-06
# ----------
# ----------
# Epoch 3600
# Training loss: 8.637331347927102e-07
# Validation loss: 8.76502298297055e-07
# ----------
# ----------
# Epoch 3650
# Training loss: 2.725064632613794e-06
# Validation loss: 1.5933082977426238e-06
# ----------
# ----------
# Epoch 3700
# Training loss: 9.49430543073504e-08
# Validation loss: 8.342004420569538e-08
# ----------
# ----------
# Epoch 3750
# Training loss: 1.5473736993953935e-06
# Validation loss: 1.4901197005201539e-06
# ----------
# ----------
# Epoch 3800
# Training loss: 1.2609820032594143e-07
# Validation loss: 9.050782523445378e-08
# ----------
# ----------
# Epoch 3850
# Training loss: 5.552362267735589e-07
# Validation loss: 3.433988524648157e-07
# ----------
# ----------
# Epoch 3900
# Training loss: 1.8469166889190092e-06
# Validation loss: 1.944987957358535e-06
# ----------
# ----------
# Epoch 3950
# Training loss: 4.0008598034546594e-07
# Validation loss: 2.1118074045034518e-07
# ----------
# Loaded best model with validation loss: 6.905274219093371e-08

# %% [markdown]
# Visualize error evolution

# %%
import matplotlib.pyplot as plt
import numpy as np

# get the losses from the trained model
val_loss = model._validation_loss
train_loss = model._training_loss

# calculate the log of the losses
val_loss = np.log(val_loss)
train_loss = np.log(train_loss)

fig, ax = plt.subplots(1, 1, figsize=(10, 5))
ax.plot(val_loss, label="Validation Loss")
ax.plot(train_loss, label="Training Loss")
ax.set_xlabel("Epoch")
ax.set_ylabel("lg(loss)")
ax.legend()
plt.show()

# %% [markdown]
# Export model to save it

# %%
model.export_model(path="./models", name="bi_input_model_v2")

# %% [markdown]
# Reload the model

# %%
model_test = BiInputModel()
model_test.load_model("./models", "bi_input_model_v2")

# %% [markdown]
# Check error size for the test set

# %%
# create data loader with test set
test_dataset = torch.utils.data.TensorDataset(x_test, y_test)
test_loader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size=1,
    shuffle=False,
    num_workers=0
)

mse = 0
mae = 0
for batch_x, batch_y in test_loader:
    y_predict = model_test.forward(batch_x.float()).detach()
    y = batch_y.detach()

    # calculate error for each batch
    mse += torch.mean((y_predict - y) ** 2)
    mae += torch.mean(torch.abs(y_predict - y))

rmse = torch.sqrt(mse)

print(f"Test RMSE: {rmse}")
print(f"Test MAE: {mae}")
# Out:
# Test RMSE: 0.0026922994293272495
# Test MAE: 0.01910918951034546

# %% [markdown]
# Predict and visualize the results

# %%
y_predict = model_test.forward(x_test.float()).detach()
y_predict.shape
# Out:
# torch.Size([90, 2, 21, 21])

# %%
from plotting import plot_data_samples

idx = 89

plot_data_samples(x_test, y_test, "Test Sample", idx)
plot_data_samples(x_test, y_predict, "Predicted Sample", idx)
plot_data_samples(x_test - x_test, y_predict - y_test, "Prediction Error", idx)
